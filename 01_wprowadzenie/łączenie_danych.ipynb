# %% [markdown]
# <a href="https://colab.research.google.com/github/adasko-a/datascience_bootcamp/blob/main/01_wprowadzenie/%C5%82%C4%85czenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
google.head()
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2026-03-20  305.460  306.0000  298.2700  301.00  44364080
# 2026-03-19  304.005  308.0600  302.3500  307.13  25075831
# 2026-03-18  309.270  312.4700  306.9320  307.69  20009815
# 2026-03-17  305.860  311.4200  305.5000  310.92  21955171
# 2026-03-16  304.350  306.4886  303.0201  305.56  23519709

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2026-03-20 to 2021-03-22
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.columns = [col if 'apple_'in col else 'apple_'+ col.lower() for col in apple.columns]
amazon.columns = [col if 'amazon_'in col else'amazon_'+ col.lower() for col in amazon.columns]
google.columns = [col if 'google_'in col else'google_'+ col.lower() for col in google.columns]
uber.columns = [col if 'uber_'in col else'uber_'+ col.lower() for col in uber.columns]
google.columns
# Out:
# Index(['google_open', 'google_high', 'google_low', 'google_close',
#        'google_volume'],
#       dtype='object')

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)

# %%
df.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2026-03-20     247.975    249.1999     246.00       247.99      88331081
# 2026-03-19     249.400    251.8300     247.30       248.96      34864082
# 2026-03-18     252.625    254.9400     249.00       249.94      35757874
# 2026-03-17     252.955    255.1300     252.18       254.23      32361607
# 2026-03-16     252.105    253.8850     249.88       252.82      32074210
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# Date
# 2026-03-20      207.400     207.5400     204.316        205.37       63694603
# 2026-03-19      207.060     209.1200     206.050        208.76       36440622
# 2026-03-18      213.925     215.1401     208.825        209.87       37846642
# 2026-03-17      212.820     215.7000     212.430        215.20       44969943
# 2026-03-16      208.350     212.7240     207.445        211.74       42209316
#
# ...

# %%
pd.set_option('display.float_format',lambda x: f' {x:.2f}')

# %%
df.describe().T
# Out:
#                  count         mean          std          min          25%  \
# apple_open     1256.00       185.14        41.76       116.55       149.24
# apple_high     1256.00       187.14        42.05       117.39       151.31
# apple_low      1256.00       183.33        41.42       115.88       147.63
# apple_close    1256.00       185.32        41.73       116.90       149.32
# apple_volume   1256.00  68010111.14  28989195.47  17910574.00  47472288.50
# amazon_open    1256.00       166.13        42.19        82.80       132.11
# amazon_high    1256.00       168.08        42.35        83.48       133.66
# amazon_low     1256.00       164.02        41.89        81.43       130.48
# amazon_close   1256.00       166.10        42.13        81.82       132.12
# amazon_volume  1256.00  56670987.06  27032431.91  11420543.00  39426993.25
# google_open    1256.00       155.46        56.37        85.09       118.81
# ...

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.47
# apple_high           1.00        1.00       1.00         1.00         -0.45
# apple_low            1.00        1.00       1.00         1.00         -0.48
# apple_close          1.00        1.00       1.00         1.00         -0.47
# apple_volume        -0.47       -0.45      -0.48        -0.47          1.00
# amazon_open          0.76        0.76       0.77         0.76         -0.29
# amazon_high          0.76        0.77       0.77         0.77         -0.29
# amazon_low           0.76        0.76       0.76         0.76         -0.30
# amazon_close         0.76        0.76       0.76         0.76         -0.29
# amazon_volume       -0.40       -0.39      -0.41        -0.40          0.57
# google_open          0.87        0.87       0.87         0.87         -0.35
# ...

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.76          0.87        0.79
# amazon_close         0.76          1.00          0.81        0.87
# google_close         0.87          0.81          1.00        0.74
# uber_close           0.79          0.87          0.74        1.00

# %% [markdown]
# #df.append()

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-06-30      91.69      93.39     91.52       93.30     16155270
# 2025-06-27      91.86      92.51     89.97       91.53     24731168
# 2025-06-26      91.30      94.38     90.88       93.12     23657765
# 2025-06-25      91.56      92.89     90.60       90.90     17400840
# 2025-06-24      87.99      92.48     87.91       91.65     38925080
# ...               ...        ...       ...         ...          ...
# 2021-06-07      50.49      51.22     49.75       50.76     16466233
# 2021-06-04      49.56      50.22     49.07       50.18     10409827
# 2021-06-03      50.43      50.50     48.53       48.70     14712859
# 2021-06-02      51.19      51.41     50.55       50.79     13484205
# 2021-06-01      51.62      51.66     49.84       50.98     16583752
#
# [103 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]

uber_6.append(uber_7)
uber_6
# nie działa dla wyzszych wersji pandas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_288/39666194.py in <cell line: 0>()
#       1 uber_7 = uber[uber.index.month == 7]
#       2
# ----> 3 uber_6.append(uber_7)
#       4 uber_6
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'
